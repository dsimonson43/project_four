# %% [markdown]
# ## Import dependencies and load in the `.csv` and `.TSV000` files and create the 5 DataFrames

# %%
# Load dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
# Load in the state Redfin data
state_df = pd.read_csv("Resources/state_market_tracker.tsv000", sep="\t")

# Load in the national Redfin data
national_df = pd.read_csv("Resources/us_national_market_tracker.tsv000", sep="\t")

# Load in the `Home Price Index` Redfin data
price_index = pd.read_csv("Resources/National_RHPI_Index.csv", encoding="utf-16", sep="\t")

# Load in the `MoM HPI Index` Redfin data
mom_index = pd.read_csv("Resources/MoM.csv", encoding="utf-16", sep="\t")

# Load in 'https://fred.stlouisfed.org/series/MORTGAGE30US'
rates_df = pd.read_csv("Resources/MORTGAGE30US.csv")

# %% [markdown]
# ## Clean up the `state_df` and `national_df` columns to align with "Date" for all of the Redfin data sources.

# %%
# Rename 'period_begin' to 'Date' 
state_df.rename(columns={"period_begin": "Date"}, inplace=True)

# Reformat to MM/DD/YY
state_df["Date"] = pd.to_datetime(state_df["Date"]).dt.strftime("%-m/%-d/%Y")

# Drop non-feature columns, including 'period_end'
columns_to_drop_state = ['period_end', 'region_type_id', 'state_code', 'property_type_id', 
                         'parent_metro_region', 'parent_metro_region_metro_code', 'last_updated']
state_df.drop(columns=columns_to_drop_state, inplace=True)

# %%
# Sort state_df by 'period_begin'
state_df = state_df.sort_values(by="Date", ascending=True)

# View the state_df
state_df.head()
# Out:
#            Date  period_duration region_type  table_id is_seasonally_adjusted  \
# 19971  1/1/2012               30       state        23                      f
# 10500  1/1/2012               30       state        10                      f
# 31826  1/1/2012               30       state        42                      f
# 4385   1/1/2012               30       state        47                      f
# 28684  1/1/2012               30       state        12                      f
#
#               region  city          state            property_type  \
# 19971       Oklahoma   NaN       Oklahoma                Townhouse
# 10500  New Hampshire   NaN  New Hampshire          All Residential
# 31826       Virginia   NaN       Virginia  Multi-Family (2-4 Unit)
# 4385        Michigan   NaN       Michigan          All Residential
# 28684     New Jersey   NaN     New Jersey          All Residential
#
#        median_sale_price  ...  avg_sale_to_list_yoy  sold_above_list  \
# 19971              87200  ...             -0.022731         0.000000
# 10500             184000  ...              0.004329         0.146886
# 31826              40000  ...             -0.037407         0.142857
# 4385               79900  ...              0.005616         0.188435
# 28684             247000  ...             -0.007615         0.054863
#
#        sold_above_list_mom  sold_above_list_yoy  price_drops  price_drops_mom  \
# 19971            -0.181818             0.000000          NaN              NaN
# 10500            -0.005915             0.010146          NaN              NaN
# 31826             0.142857             0.017857          NaN              NaN
# 4385              0.008916             0.011066          NaN              NaN
# 28684            -0.003108            -0.007739     0.000549         0.000502
#
#        price_drops_yoy  off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 19971              NaN                 0.000000                     0.000000
# 10500              NaN                 0.007093                     0.000636
# 31826              NaN                 0.000000                     0.000000
# 4385               NaN                 0.013045                    -0.000528
# 28684              NaN                 0.007897                     0.001832
#
#        off_market_in_two_weeks_yoy
# 19971                     0.000000
# 10500                    -0.000240
# 31826                     0.000000
# 4385                      0.000734
# 28684                     0.006060
#
# [5 rows x 51 columns]

# %%
# Check for date range of DataFrame end dates of the state_df
first_date = state_df["Date"].min()
last_date = state_df["Date"].max()

# Display results
print(f"Beginning Date: {first_date}")
print(f"End Date: {last_date}")
# Out:
# Beginning Date: 1/1/2012
# End Date: 9/1/2024

# %%
# Rename 'period_begin' to 'Date' 
national_df.rename(columns={"period_begin": "Date"}, inplace=True)

# Reformat to MM/DD/YY
national_df["Date"] = pd.to_datetime(national_df["Date"]).dt.strftime("%-m/%-d/%Y")

# Drop non-feature columns, including 'period_end'
columns_to_drop_national = ['period_end', 'region_type_id', 'state_code', 'property_type_id', 
                         'parent_metro_region', 'parent_metro_region_metro_code', 'last_updated']
national_df.drop(columns=columns_to_drop_national, inplace=True)

# %%
# Sort national_df by 'period_begin'
national_df = national_df.sort_values(by="Date", ascending=True)

# View the national_df
national_df.head()
# Out:
#          Date  period_duration region_type  table_id is_seasonally_adjusted  \
# 452  1/1/2012               30    national      1400                      f
# 642  1/1/2012               30    national      1400                      t
# 628  1/1/2012               30    national      1400                      f
# 623  1/1/2012               30    national      1400                      f
# 796  1/1/2012               30    national      1400                      f
#
#         region      city state              property_type  median_sale_price  \
# 452   National  National  U.S.          Single Units Only      159562.000000
# 642   National  National  U.S.            All Residential      170767.650108
# 628   National  National  U.S.  Single Family Residential      164394.000000
# 623   National  National  U.S.                  Townhouse      150997.000000
# 796   National  National  U.S.                Condo/Co-op      134728.000000
#
#      ...  avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  \
# 452  ...              0.002164         0.173126             0.002568
# 642  ...                   NaN         0.199349                  NaN
# 628  ...              0.002501         0.176420             0.002771
# 623  ...              0.002163         0.171398             0.003141
# 796  ...             -0.000079         0.152783             0.001507
#
#      sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 452             0.004076     0.066841         0.012491        -0.011568
# 642                  NaN     0.068864              NaN              NaN
# 628             0.007864     0.065524         0.012231        -0.011690
# 623             0.003095     0.069660         0.012516        -0.011709
# 796            -0.019809     0.073374         0.014090        -0.010111
#
#      off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 452                 0.104603                     0.027196
# 642                 0.119988                          NaN
# 628                 0.104181                     0.026586
# 623                 0.100036                     0.025608
# 796                 0.107596                     0.029637
#
#      off_market_in_two_weeks_yoy
# 452                     0.029610
# 642                          NaN
# 628                     0.029462
# 623                     0.026326
# 796                     0.032152
#
# [5 rows x 51 columns]

# %% [markdown]
# ## Create the HPI Index file by merging the monthly Index SA (Seasonally Adjusted) price index with the MoM (Month over  Month) changes for both Redfins HPI and Case Shillers price index.

# %%
# Update the column name to match Redfin website chart
price_index.rename(columns={"Unnamed: 1": "Index SA"}, inplace=True)

# View the price_index
price_index.head()
# Out:
#        Date  Index SA
# 0  1/1/2012      59.9
# 1  2/1/2012      60.4
# 2  3/1/2012      60.8
# 3  4/1/2012      61.2
# 4  5/1/2012      61.5

# %%
# Reorder columns in mom_index
new_order = ["Date", "Redfin HPI MoM", "Case Shiller Index MoM"]

mom_index = mom_index[new_order]

# Verify the new column order
mom_index.head()
# Out:
#        Date Redfin HPI MoM  Case Shiller Index MoM
# 0  1/1/2012          0.00%                -0.00048
# 1  2/1/2012          0.00%                -0.00056
# 2  3/1/2012          0.00%                 0.01004
# 3  4/1/2012          0.72%                 0.00907
# 4  5/1/2012          0.62%                 0.00719

# %%
# Combine the HPI and MoM data
hpi_index = pd.merge(price_index, mom_index, on="Date", how="inner")
hpi_index.head()
# Out:
#        Date  Index SA Redfin HPI MoM  Case Shiller Index MoM
# 0  1/1/2012      59.9          0.00%                -0.00048
# 1  2/1/2012      60.4          0.00%                -0.00056
# 2  3/1/2012      60.8          0.00%                 0.01004
# 3  4/1/2012      61.2          0.72%                 0.00907
# 4  5/1/2012      61.5          0.62%                 0.00719

# %%
# Check for date range of DataFrame end dates of the hpi_index
first = hpi_index["Date"].min()
last = hpi_index["Date"].max()

# Display results
print(f"Beginning Date: {first}")
print(f"End Date: {last}")
# Out:
# Beginning Date: 1/1/2012
# End Date: 9/1/2024

# %% [markdown]
# ## Check the data types structures and statistics for the 4 DataFrames to confirm which datasets to merge and where.

# %%
# Check the shape and data breakdown for hpi_index
hpi_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    158 non-null    object
#  1   Index SA                158 non-null    float64
#  2   Redfin HPI MoM          158 non-null    object
#  3   Case Shiller Index MoM  158 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 5.1+ KB

# %%
# Rename the columns to be in line with hpi_index 
rates_df.rename(columns={"observation_date": "Date", "MORTGAGE30US": "30_Year_%"}, inplace=True)

# Convert the 'Date' column to a datetime object and reformat it to 'MM/DD/YYYY'
rates_df["Date"] = pd.to_datetime(rates_df["Date"]).dt.strftime("%-m/%-d/%Y")

# View rates_df
rates_df.tail()
# Out:
#           Date  30_Year_%
# 682  1/30/2025       6.95
# 683   2/6/2025       6.89
# 684  2/13/2025       6.87
# 685  2/20/2025       6.85
# 686  2/27/2025       6.76

# %%
# Check the shape and data breakdown for rates_df
rates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687 entries, 0 to 686
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       687 non-null    object
#  1   30_Year_%  687 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.9+ KB

# %%
# Check for date range of DataFrame end dates of the rates_df
print(rates_df["Date"].unique())
# Out:
# 1/10/2013
# 9/9/2021
# ['1/5/2012' '1/12/2012' '1/19/2012' '1/26/2012' '2/2/2012' '2/9/2012'
#  '2/16/2012' '2/23/2012' '3/1/2012' '3/8/2012' '3/15/2012' '3/22/2012'
#  '3/29/2012' '4/5/2012' '4/12/2012' '4/19/2012' '4/26/2012' '5/3/2012'
#  '5/10/2012' '5/17/2012' '5/24/2012' '5/31/2012' '6/7/2012' '6/14/2012'
#  '6/21/2012' '6/28/2012' '7/5/2012' '7/12/2012' '7/19/2012' '7/26/2012'
#  '8/2/2012' '8/9/2012' '8/16/2012' '8/23/2012' '8/30/2012' '9/6/2012'
#  '9/13/2012' '9/20/2012' '9/27/2012' '10/4/2012' '10/11/2012' '10/18/2012'
#  '10/25/2012' '11/1/2012' '11/8/2012' '11/15/2012' '11/21/2012'
#  '11/29/2012' '12/6/2012' '12/13/2012' '12/20/2012' '12/27/2012'
#  '1/3/2013' '1/10/2013' '1/17/2013' '1/24/2013' '1/31/2013' '2/7/2013'
#  '6/8/2023' '6/15/2023' '6/22/2023' '6/29/2023' '7/6/2023' '7/13/2023'
#  '7/20/2023' '7/27/2023' '8/3/2023' '8/10/2023' '8/17/2023' '8/24/2023'
#  '8/31/2023' '9/7/2023' '9/14/2023' '9/21/2023' '9/28/2023' '10/5/2023'
#  '10/12/2023' '10/19/2023' '10/26/2023' '11/2/2023' '11/9/2023'
#  '11/16/2023' '11/22/2023' '11/30/2023' '12/7/2023' '12/14/2023'
#  '12/21/2023' '12/28/2023' '1/4/2024' '1/11/2024' '1/18/2024' '1/25/2024'
#  '2/1/2024' '2/8/2024' '2/15/2024' '2/22/2024' '2/29/2024' '3/7/2024'
#  '3/14/2024' '3/21/2024' '3/28/2024' '4/4/2024' '4/11/2024' '4/18/2024'
#  '4/25/2024' '5/2/2024' '5/9/2024' '5/16/2024' '5/23/2024' '5/30/2024'
#  '6/6/2024' '6/13/2024' '6/20/2024' '6/27/2024' '7/3/2024' '7/11/2024'
#  '7/18/2024' '7/25/2024' '8/1/2024' '8/8/2024' '8/15/2024' '8/22/2024'
#  '8/29/2024' '9/5/2024' '9/12/2024' '9/19/2024' '9/26/2024' '10/3/2024'
#  '10/10/2024' '10/17/2024' '10/24/2024' '10/31/2024' '11/7/2024'
#  '11/14/2024' '11/21/2024' '11/27/2024' '12/5/2024' '12/12/2024'
#  '12/19/2024' '12/26/2024' '1/2/2025' '1/9/2025' '1/16/2025' '1/23/2025'
#  '1/30/2025' '2/6/2025' '2/13/2025' '2/20/2025' '2/27/2025']

# %%
# Check the stats for state_df
state_df.describe()
# Out:
#        period_duration      table_id  city  median_sale_price  \
# count          39054.0  39054.000000   0.0       3.905400e+04
# mean              30.0     26.044272   NaN       2.742932e+05
# std                0.0     14.661014   NaN       1.657464e+05
# min               30.0      1.000000   NaN       7.000000e+03
# 25%               30.0     13.000000   NaN       1.686000e+05
# 50%               30.0     26.000000   NaN       2.302000e+05
# 75%               30.0     39.000000   NaN       3.294750e+05
# max               30.0     51.000000   NaN       3.275000e+06
#
#        median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# count           39054.000000           39054.000000       3.894800e+04
# mean                0.021081               0.088713       3.038891e+05
# std                 0.256906               0.250174       1.645740e+05
# min                -0.913000              -0.941347       5.300000e+04
# 25%                -0.029909               0.014501       1.999000e+05
# 50%                 0.004885               0.063599       2.600000e+05
# 75%                 0.044059               0.127140       3.634000e+05
# max                22.152709              12.571429       4.700000e+06
#
#        median_list_price_mom  median_list_price_yoy   median_ppsf  ...  \
# count           38886.000000           38869.000000  38937.000000  ...
# mean                0.008675               0.066152    172.388910  ...
# std                 0.076484               0.084074    282.322977  ...
# min                -0.743884              -0.725075      3.000000  ...
# 25%                -0.027343               0.024691    101.000000  ...
# 50%                 0.001303               0.058138    138.000000  ...
# 75%                 0.036497               0.098160    198.000000  ...
# max                 3.578644               3.630526  40906.000000  ...
#
#        avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  \
# count          37628.000000     39003.000000         39003.000000
# mean               0.002766         0.208941             0.000308
# std                0.025963         0.142651             0.076999
# min               -0.539383         0.000000            -1.000000
# 25%               -0.003721         0.114130            -0.019844
# 50%                0.002735         0.181818             0.000000
# 75%                0.009572         0.283181             0.020287
# max                0.650629         1.000000             1.000000
#
#        sold_above_list_yoy   price_drops  price_drops_mom  price_drops_yoy  \
# count         39003.000000  30865.000000     30396.000000     28703.000000
# mean              0.008471      0.163705         0.001198         0.012557
# std               0.102753      0.087796         0.047395         0.063022
# min              -1.000000      0.000009        -0.888889        -0.800000
# 25%              -0.023244      0.103659        -0.017844        -0.016846
# 50%               0.005443      0.158801         0.002350         0.005715
# 75%               0.043603      0.218351         0.021613         0.035509
# max               1.000000      1.000000         0.645299         0.681287
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# count             38903.000000                 38835.000000
# mean                  0.252904                     0.001960
# std                   0.195527                     0.078571
# min                   0.000000                    -1.000000
# 25%                   0.059043                    -0.024598
# 50%                   0.248948                     0.000000
# 75%                   0.394383                     0.025743
# max                   1.000000                     1.000000
#
#        off_market_in_two_weeks_yoy
# count                 38812.000000
# mean                      0.025447
# std                       0.109723
# min                      -1.000000
# 25%                      -0.012868
# 50%                       0.009057
# 75%                       0.064291
# max                       1.000000
#
# [8 rows x 45 columns]

# %%
# Check the shape and data breakdown for state_df
state_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39054 entries, 19971 to 12650
# Data columns (total 51 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         39054 non-null  object
#  1   period_duration              39054 non-null  int64
#  2   region_type                  39054 non-null  object
#  3   table_id                     39054 non-null  int64
#  4   is_seasonally_adjusted       39054 non-null  object
#  5   region                       39054 non-null  object
#  6   city                         0 non-null      float64
#  7   state                        39054 non-null  object
#  8   property_type                39054 non-null  object
#  9   median_sale_price            39054 non-null  int64
#  10  median_sale_price_mom        39054 non-null  float64
#  11  median_sale_price_yoy        39054 non-null  float64
#  12  median_list_price            38948 non-null  float64
#  13  median_list_price_mom        38886 non-null  float64
#  14  median_list_price_yoy        38869 non-null  float64
#  15  median_ppsf                  38937 non-null  float64
#  16  median_ppsf_mom              39037 non-null  float64
#  17  median_ppsf_yoy              39041 non-null  float64
#  18  median_list_ppsf             38948 non-null  float64
#  19  median_list_ppsf_mom         38886 non-null  float64
#  20  median_list_ppsf_yoy         38869 non-null  float64
#  21  homes_sold                   39054 non-null  int64
#  22  homes_sold_mom               39054 non-null  float64
#  23  homes_sold_yoy               39054 non-null  float64
#  24  pending_sales                38956 non-null  float64
#  25  pending_sales_mom            38938 non-null  float64
#  26  pending_sales_yoy            38925 non-null  float64
#  27  new_listings                 38948 non-null  float64
#  28  new_listings_mom             38886 non-null  float64
#  29  new_listings_yoy             38869 non-null  float64
#  30  inventory                    38971 non-null  float64
#  31  inventory_mom                38965 non-null  float64
#  32  inventory_yoy                38956 non-null  float64
#  33  months_of_supply             38971 non-null  float64
#  34  months_of_supply_mom         38965 non-null  float64
#  35  months_of_supply_yoy         38956 non-null  float64
#  36  median_dom                   39031 non-null  float64
#  37  median_dom_mom               39025 non-null  float64
#  38  median_dom_yoy               39025 non-null  float64
#  39  avg_sale_to_list             37799 non-null  float64
#  40  avg_sale_to_list_mom         37688 non-null  float64
#  41  avg_sale_to_list_yoy         37628 non-null  float64
#  42  sold_above_list              39003 non-null  float64
#  43  sold_above_list_mom          39003 non-null  float64
#  44  sold_above_list_yoy          39003 non-null  float64
#  45  price_drops                  30865 non-null  float64
#  46  price_drops_mom              30396 non-null  float64
#  47  price_drops_yoy              28703 non-null  float64
#  48  off_market_in_two_weeks      38903 non-null  float64
#  49  off_market_in_two_weeks_mom  38835 non-null  float64
#  50  off_market_in_two_weeks_yoy  38812 non-null  float64
# dtypes: float64(41), int64(4), object(6)
# memory usage: 15.5+ MB

# %%
# Check the stats for national_df
national_df.describe()
# Out:
#        period_duration  table_id  median_sale_price  median_sale_price_mom  \
# count           1738.0    1738.0        1738.000000            1733.000000
# mean              30.0    1400.0      286493.388234               0.006178
# std                0.0       0.0       80656.713597               0.021647
# min               30.0    1400.0      130975.000000              -0.143796
# 25%               30.0    1400.0      221433.250000              -0.004585
# 50%               30.0    1400.0      270385.673069               0.005583
# 75%               30.0    1400.0      352252.215293               0.014934
# max               30.0    1400.0      480069.000000               0.119120
#
#        median_sale_price_yoy  median_list_price  median_list_price_mom  \
# count            1678.000000        1738.000000            1733.000000
# mean                0.074891      298560.925160               0.006763
# std                 0.050004       81834.461136               0.031055
# min                -0.071733      148511.000000              -0.110785
# 25%                 0.045457      233638.061937              -0.008107
# 50%                 0.066117      283509.226120               0.004287
# 75%                 0.100633      362129.924387               0.014243
# max                 0.291577      550229.000000               0.177777
#
#        median_list_price_yoy  median_ppsf  median_ppsf_mom  ...  \
# count            1678.000000  1738.000000      1733.000000  ...
# mean                0.071123   170.516200         0.006023  ...
# std                 0.041014    52.816614         0.019261  ...
# min                -0.028655    67.000000        -0.122746  ...
# 25%                 0.041776   129.019677        -0.003144  ...
# 50%                 0.063884   157.000000         0.005065  ...
# 75%                 0.096644   214.830888         0.014720  ...
# max                 0.228002   319.653928         0.152847  ...
#
#        avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  \
# count           1678.000000      1738.000000          1733.000000
# mean               0.002367         0.268276             0.000483
# std                0.010424         0.088036             0.018612
# min               -0.038200         0.140760            -0.099338
# 25%               -0.001758         0.210687            -0.008016
# 50%                0.002871         0.239732            -0.000202
# 75%                0.005892         0.294808             0.008204
# max                0.042060         0.602377             0.072822
#
#        sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# count          1678.000000  1738.000000      1733.000000      1678.000000
# mean              0.008212     0.111060         0.000774         0.007476
# std               0.079706     0.037923         0.018440         0.030579
# min              -0.282408     0.037674        -0.200867        -0.216351
# 25%              -0.024453     0.082755        -0.003842        -0.010829
# 50%               0.013924     0.109658         0.001582         0.003528
# 75%               0.031742     0.136298         0.007702         0.024695
# max               0.312275     0.322287         0.201428         0.199815
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# count              1738.000000                  1733.000000
# mean                  0.331898                     0.001665
# std                   0.126744                     0.030051
# min                   0.100036                    -0.116967
# 25%                   0.228934                    -0.014392
# 50%                   0.334078                    -0.000737
# 75%                   0.407688                     0.014049
# max                   0.688481                     0.101049
#
#        off_market_in_two_weeks_yoy
# count                  1678.000000
# mean                      0.019804
# std                       0.073017
# min                      -0.258460
# 25%                      -0.006290
# 50%                       0.028485
# 75%                       0.054311
# max                       0.281640
#
# [8 rows x 44 columns]

# %%
# Check the shape and data breakdown for national_df
national_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1738 entries, 452 to 1403
# Data columns (total 51 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1738 non-null   object
#  1   period_duration              1738 non-null   int64
#  2   region_type                  1738 non-null   object
#  3   table_id                     1738 non-null   int64
#  4   is_seasonally_adjusted       1738 non-null   object
#  5   region                       1738 non-null   object
#  6   city                         1738 non-null   object
#  7   state                        1738 non-null   object
#  8   property_type                1738 non-null   object
#  9   median_sale_price            1738 non-null   float64
#  10  median_sale_price_mom        1733 non-null   float64
#  11  median_sale_price_yoy        1678 non-null   float64
#  12  median_list_price            1738 non-null   float64
#  13  median_list_price_mom        1733 non-null   float64
#  14  median_list_price_yoy        1678 non-null   float64
#  15  median_ppsf                  1738 non-null   float64
#  16  median_ppsf_mom              1733 non-null   float64
#  17  median_ppsf_yoy              1678 non-null   float64
#  18  median_list_ppsf             1738 non-null   float64
#  19  median_list_ppsf_mom         1733 non-null   float64
#  20  median_list_ppsf_yoy         1678 non-null   float64
#  21  homes_sold                   1738 non-null   float64
#  22  homes_sold_mom               1733 non-null   float64
#  23  homes_sold_yoy               1678 non-null   float64
#  24  pending_sales                1738 non-null   float64
#  25  pending_sales_mom            1733 non-null   float64
#  26  pending_sales_yoy            1678 non-null   float64
#  27  new_listings                 1738 non-null   float64
#  28  new_listings_mom             1733 non-null   float64
#  29  new_listings_yoy             1678 non-null   float64
#  30  inventory                    1738 non-null   float64
#  31  inventory_mom                1733 non-null   float64
#  32  inventory_yoy                1678 non-null   float64
#  33  months_of_supply             1738 non-null   float64
#  34  months_of_supply_mom         1733 non-null   float64
#  35  months_of_supply_yoy         1678 non-null   float64
#  36  median_dom                   1738 non-null   float64
#  37  median_dom_mom               1733 non-null   float64
#  38  median_dom_yoy               1678 non-null   float64
#  39  avg_sale_to_list             1738 non-null   float64
#  40  avg_sale_to_list_mom         1733 non-null   float64
#  41  avg_sale_to_list_yoy         1678 non-null   float64
#  42  sold_above_list              1738 non-null   float64
#  43  sold_above_list_mom          1733 non-null   float64
#  44  sold_above_list_yoy          1678 non-null   float64
#  45  price_drops                  1738 non-null   float64
#  46  price_drops_mom              1733 non-null   float64
#  47  price_drops_yoy              1678 non-null   float64
#  48  off_market_in_two_weeks      1738 non-null   float64
#  49  off_market_in_two_weeks_mom  1733 non-null   float64
#  50  off_market_in_two_weeks_yoy  1678 non-null   float64
# dtypes: float64(42), int64(2), object(7)
# memory usage: 706.1+ KB

# %% [markdown]
# ## Create copies of the 4 DataFrames, setting aside the originals for comparison and plotting. Merge the copied versions `state_df_copy` and `hpi_index_copy`.

# %%
# Create copies of the DataFrames
state_df_copy = state_df.copy()
national_df_copy = national_df.copy()
hpi_index_copy = hpi_index.copy()
rates_df_copy = rates_df.copy()

# %%
# Combine state and hpi DataFrames
combined_df = pd.merge(state_df_copy, hpi_index_copy, on="Date", how="inner")

# Reorder columns in combined_df
column_order = ["Date"] + hpi_index_copy.columns.tolist()[1:] + state_df_copy.columns.tolist()[1:]
combined_df = combined_df[column_order]

# Verify the results
combined_df.head()
# Out:
#        Date  Index SA Redfin HPI MoM  Case Shiller Index MoM  period_duration  \
# 0  1/1/2012      59.9          0.00%                -0.00048               30
# 1  1/1/2012      59.9          0.00%                -0.00048               30
# 2  1/1/2012      59.9          0.00%                -0.00048               30
# 3  1/1/2012      59.9          0.00%                -0.00048               30
# 4  1/1/2012      59.9          0.00%                -0.00048               30
#
#   region_type  table_id is_seasonally_adjusted         region  city  ...  \
# 0       state        23                      f       Oklahoma   NaN  ...
# 1       state        10                      f  New Hampshire   NaN  ...
# 2       state        42                      f       Virginia   NaN  ...
# 3       state        47                      f       Michigan   NaN  ...
# 4       state        12                      f     New Jersey   NaN  ...
#
#   avg_sale_to_list_yoy sold_above_list  sold_above_list_mom  \
# 0            -0.022731        0.000000            -0.181818
# 1             0.004329        0.146886            -0.005915
# 2            -0.037407        0.142857             0.142857
# 3             0.005616        0.188435             0.008916
# 4            -0.007615        0.054863            -0.003108
#
#    sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0             0.000000          NaN              NaN              NaN
# 1             0.010146          NaN              NaN              NaN
# 2             0.017857          NaN              NaN              NaN
# 3             0.011066          NaN              NaN              NaN
# 4            -0.007739     0.000549         0.000502              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.000000                     0.000000
# 1                 0.007093                     0.000636
# 2                 0.000000                     0.000000
# 3                 0.013045                    -0.000528
# 4                 0.007897                     0.001832
#
#    off_market_in_two_weeks_yoy
# 0                     0.000000
# 1                    -0.000240
# 2                     0.000000
# 3                     0.000734
# 4                     0.006060
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Update the `rates_df` date and average the the interest rates. Reason is the start date would require back filling as we have 1/1/2012 (monthly) `combined_df`and 1/5/2012 as our start date for `rates_df`(off weekly). This adds in the interest rate feature to our combined data set.
#
# **Example, the first month is (3.91 + 3.89 + 3.88 + 3.98) / 4 = 3.915.**

# %%
# Convert 'Date' in rates_df_copy to datetime for easier processing
rates_df_copy["Date"] = pd.to_datetime(rates_df_copy["Date"])

# Extract year and month from weekly dates (Makes it a Year-Month format)
rates_df_copy["Month"] = rates_df_copy["Date"].dt.to_period("M")  

# Aggregate by month (Average 30-Year rate for each month)
rates_monthly = rates_df_copy.groupby("Month").agg({"30_Year_%": "mean"}).reset_index()

# Confirm data types
rates_monthly.dtypes
# Out:
# Month        period[M]
# 30_Year_%      float64
# dtype: object

# %%
rates_monthly.head()
# Out:
#      Month  30_Year_%
# 0  2012-01      3.915
# 1  2012-02      3.890
# 2  2012-03      3.954
# 3  2012-04      3.910
# 4  2012-05      3.798

# %%
rates_monthly.dtypes
# Out:
# Month        period[M]
# 30_Year_%      float64
# dtype: object

# %%
# Convert 'Month' (period[M]) to datetime format
rates_monthly["Date"] = rates_monthly["Month"].dt.to_timestamp()

# Format 'Date' to MM/DD/YYYY
rates_monthly["Date"] = rates_monthly["Date"].dt.strftime("%-m/%-d/%Y")

# %%
# Re-confirm the rates_monthly data types 
rates_monthly.dtypes
# Out:
# Month        period[M]
# 30_Year_%      float64
# Date            object
# dtype: object

# %%
# Drop the 'Month' column
rates_monthly.drop(columns=["Month"], inplace=True)

# Verify the results
rates_monthly.head()
# Out:
#    30_Year_%      Date
# 0      3.915  1/1/2012
# 1      3.890  2/1/2012
# 2      3.954  3/1/2012
# 3      3.910  4/1/2012
# 4      3.798  5/1/2012

# %%
# Merge with combined_df
complete_df = pd.merge(combined_df, rates_monthly, on="Date", how="inner")

# Verify the result
complete_df.head()
# Out:
#        Date  Index SA Redfin HPI MoM  Case Shiller Index MoM  period_duration  \
# 0  1/1/2012      59.9          0.00%                -0.00048               30
# 1  1/1/2012      59.9          0.00%                -0.00048               30
# 2  1/1/2012      59.9          0.00%                -0.00048               30
# 3  1/1/2012      59.9          0.00%                -0.00048               30
# 4  1/1/2012      59.9          0.00%                -0.00048               30
#
#   region_type  table_id is_seasonally_adjusted         region  city  ...  \
# 0       state        23                      f       Oklahoma   NaN  ...
# 1       state        10                      f  New Hampshire   NaN  ...
# 2       state        42                      f       Virginia   NaN  ...
# 3       state        47                      f       Michigan   NaN  ...
# 4       state        12                      f     New Jersey   NaN  ...
#
#   sold_above_list sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0        0.000000           -0.181818             0.000000          NaN
# 1        0.146886           -0.005915             0.010146          NaN
# 2        0.142857            0.142857             0.017857          NaN
# 3        0.188435            0.008916             0.011066          NaN
# 4        0.054863           -0.003108            -0.007739     0.000549
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0              NaN              NaN                 0.000000
# 1              NaN              NaN                 0.007093
# 2              NaN              NaN                 0.000000
# 3              NaN              NaN                 0.013045
# 4         0.000502              NaN                 0.007897
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  30_Year_%
# 0                     0.000000                     0.000000      3.915
# 1                     0.000636                    -0.000240      3.915
# 2                     0.000000                     0.000000      3.915
# 3                    -0.000528                     0.000734      3.915
# 4                     0.001832                     0.006060      3.915
#
# [5 rows x 55 columns]

# %%
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39054 entries, 0 to 39053
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         39054 non-null  object
#  1   Index SA                     39054 non-null  float64
#  2   Redfin HPI MoM               39054 non-null  object
#  3   Case Shiller Index MoM       39054 non-null  float64
#  4   period_duration              39054 non-null  int64
#  5   region_type                  39054 non-null  object
#  6   table_id                     39054 non-null  int64
#  7   is_seasonally_adjusted       39054 non-null  object
#  8   region                       39054 non-null  object
#  9   city                         0 non-null      float64
#  10  state                        39054 non-null  object
#  11  property_type                39054 non-null  object
#  12  median_sale_price            39054 non-null  int64
#  13  median_sale_price_mom        39054 non-null  float64
#  14  median_sale_price_yoy        39054 non-null  float64
#  15  median_list_price            38948 non-null  float64
#  16  median_list_price_mom        38886 non-null  float64
#  17  median_list_price_yoy        38869 non-null  float64
#  18  median_ppsf                  38937 non-null  float64
#  19  median_ppsf_mom              39037 non-null  float64
#  20  median_ppsf_yoy              39041 non-null  float64
#  21  median_list_ppsf             38948 non-null  float64
#  22  median_list_ppsf_mom         38886 non-null  float64
#  23  median_list_ppsf_yoy         38869 non-null  float64
#  24  homes_sold                   39054 non-null  int64
#  25  homes_sold_mom               39054 non-null  float64
#  26  homes_sold_yoy               39054 non-null  float64
#  27  pending_sales                38956 non-null  float64
#  28  pending_sales_mom            38938 non-null  float64
#  29  pending_sales_yoy            38925 non-null  float64
#  30  new_listings                 38948 non-null  float64
#  31  new_listings_mom             38886 non-null  float64
#  32  new_listings_yoy             38869 non-null  float64
#  33  inventory                    38971 non-null  float64
#  34  inventory_mom                38965 non-null  float64
#  35  inventory_yoy                38956 non-null  float64
#  36  months_of_supply             38971 non-null  float64
#  37  months_of_supply_mom         38965 non-null  float64
#  38  months_of_supply_yoy         38956 non-null  float64
#  39  median_dom                   39031 non-null  float64
#  40  median_dom_mom               39025 non-null  float64
#  41  median_dom_yoy               39025 non-null  float64
#  42  avg_sale_to_list             37799 non-null  float64
#  43  avg_sale_to_list_mom         37688 non-null  float64
#  44  avg_sale_to_list_yoy         37628 non-null  float64
#  45  sold_above_list              39003 non-null  float64
#  46  sold_above_list_mom          39003 non-null  float64
#  47  sold_above_list_yoy          39003 non-null  float64
#  48  price_drops                  30865 non-null  float64
#  49  price_drops_mom              30396 non-null  float64
#  50  price_drops_yoy              28703 non-null  float64
#  51  off_market_in_two_weeks      38903 non-null  float64
#  52  off_market_in_two_weeks_mom  38835 non-null  float64
#  53  off_market_in_two_weeks_yoy  38812 non-null  float64
#  54  30_Year_%                    39054 non-null  float64
# dtypes: float64(44), int64(4), object(7)
# memory usage: 16.4+ MB

# %%
# Find the minimum and maximum dates
min_date = complete_df["Date"].min()
max_date = complete_df["Date"].max()

# Print the results
print(f"Minimum Date: {min_date}")
print(f"Maximum Date: {max_date}")
# Out:
# Minimum Date: 1/1/2012
# Maximum Date: 9/1/2024

# %% [markdown]
# ## Address all rows with missing values > 0.50%.

# %%
# Remove 'city' column as no values exist
complete_df.drop(columns=["city"], inplace=True)

# Update the Missing Price Drops with 0 as reference no price drops during that month from that region
complete_df["price_drops"].fillna(0, inplace=True)
complete_df["price_drops_mom"].fillna(0, inplace=True)
complete_df["price_drops_yoy"].fillna(0, inplace=True)

# Create new columns to flag instance where price drops are blanks - creates a feauture 
complete_df["price_drops_is_blank"] = complete_df["price_drops"] == 0
complete_df["price_drops_mom_is_blank"] = complete_df["price_drops_mom"] == 0
complete_df["price_drops_yoy_is_blank"] = complete_df["price_drops_yoy"] == 0

# Use Mean for missing row values for the Average List to Sale Prices 
complete_df["avg_sale_to_list"].fillna(complete_df["avg_sale_to_list"].mean(), inplace=True)
complete_df["avg_sale_to_list_mom"].fillna(complete_df["avg_sale_to_list_mom"].mean(), inplace=True)
complete_df["avg_sale_to_list_yoy"].fillna(complete_df["avg_sale_to_list_yoy"].mean(), inplace=True)

# %%
# Fill missing values with 0 for the specified columns
complete_df["off_market_in_two_weeks"].fillna(0, inplace=True)
complete_df["off_market_in_two_weeks_mom"].fillna(0, inplace=True)
complete_df["off_market_in_two_weeks_yoy"].fillna(0, inplace=True)

# Confirm the changes
print(complete_df[["off_market_in_two_weeks", "off_market_in_two_weeks_mom", "off_market_in_two_weeks_yoy"]].isnull().sum())
# Out:
# off_market_in_two_weeks        0
# off_market_in_two_weeks_mom    0
# off_market_in_two_weeks_yoy    0
# dtype: int64

# %%
# Fill missing values in median-related columns with their column averages
columns_to_fill = [
    "median_list_price", "median_list_price_mom", "median_list_price_yoy",
    "median_ppsf", "median_ppsf_mom", "median_ppsf_yoy",
    "median_list_ppsf", "median_list_ppsf_mom", "median_list_ppsf_yoy"
]

# Apply mean imputation
for column in columns_to_fill:
    complete_df[column].fillna(complete_df[column].mean(), inplace=True)

# Verify the changes
print(complete_df[columns_to_fill].isnull().sum())
# Out:
# median_list_price        0
# median_list_price_mom    0
# median_list_price_yoy    0
# median_ppsf              0
# median_ppsf_mom          0
# median_ppsf_yoy          0
# median_list_ppsf         0
# median_list_ppsf_mom     0
# median_list_ppsf_yoy     0
# dtype: int64

# %%
# Determine the percentage of null values present
missing_percent = complete_df.isnull().mean() * 100
print(missing_percent)
# Out:
# Date                           0.000000
# Index SA                       0.000000
# Redfin HPI MoM                 0.000000
# Case Shiller Index MoM         0.000000
# period_duration                0.000000
# region_type                    0.000000
# table_id                       0.000000
# is_seasonally_adjusted         0.000000
# region                         0.000000
# state                          0.000000
# property_type                  0.000000
# median_sale_price              0.000000
# median_sale_price_mom          0.000000
# median_sale_price_yoy          0.000000
# median_list_price              0.000000
# median_list_price_mom          0.000000
# median_list_price_yoy          0.000000
# median_ppsf                    0.000000
# median_ppsf_mom                0.000000
# median_ppsf_yoy                0.000000
# median_list_ppsf               0.000000
# median_list_ppsf_mom           0.000000
# median_list_ppsf_yoy           0.000000
# homes_sold                     0.000000
# homes_sold_mom                 0.000000
# homes_sold_yoy                 0.000000
# pending_sales                  0.250935
# pending_sales_mom              0.297025
# pending_sales_yoy              0.330312
# new_listings                   0.271419
# new_listings_mom               0.430174
# new_listings_yoy               0.473703
# inventory                      0.212526
# inventory_mom                  0.227890
# inventory_yoy                  0.250935
# months_of_supply               0.212526
# months_of_supply_mom           0.227890
# months_of_supply_yoy           0.250935
# median_dom                     0.058893
# median_dom_mom                 0.074256
# median_dom_yoy                 0.074256
# avg_sale_to_list               0.000000
# avg_sale_to_list_mom           0.000000
# avg_sale_to_list_yoy           0.000000
# sold_above_list                0.130588
# sold_above_list_mom            0.130588
# sold_above_list_yoy            0.130588
# price_drops                    0.000000
# price_drops_mom                0.000000
# price_drops_yoy                0.000000
# off_market_in_two_weeks        0.000000
# off_market_in_two_weeks_mom    0.000000
# off_market_in_two_weeks_yoy    0.000000
# 30_Year_%                      0.000000
# price_drops_is_blank           0.000000
# price_drops_mom_is_blank       0.000000
# price_drops_yoy_is_blank       0.000000
# dtype: float64

# %%
# Save the DataFrame as a CSV file
complete_df.to_csv("Resources/complete_data.csv", index=False)

# Print confirmation
print("CSV file has been saved successfully as 'complete_data.csv'")
# Out:
# CSV file has been saved successfully as 'complete_data.csv'
